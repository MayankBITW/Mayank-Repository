# %%
pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      -------------------------------------- 949.2/949.2 kB 8.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------------- ------- 1.3/1.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.5 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.18.2-py3-none-any.whl size=139153 sha256=f54593d5235047a679e66b61f7c96007880fa6ab75b79af8c7a82d495d10f8d1
# ...

# %%
import yfinance as yf
ticker = 'AAPL'
stock = yf.Ticker(ticker)
balance_sheet = stock.balance_sheet
income_statement = stock.financials
print("Balance Sheet:")
print(balance_sheet.head())
print("\nIncome Statement:")
print(income_statement.head())
# Out:
# Balance Sheet:
#                           2024-09-30    2023-09-30    2022-09-30  \
# Treasury Shares Number           NaN  0.000000e+00           NaN
# Ordinary Shares Number  1.511679e+10  1.555006e+10  1.594342e+10
# Share Issued            1.511679e+10  1.555006e+10  1.594342e+10
# Net Debt                7.668600e+10  8.112300e+10  9.642300e+10
# Total Debt              1.066290e+11  1.110880e+11  1.324800e+11
#
#                           2021-09-30  2020-09-30
# Treasury Shares Number           NaN         NaN
# Ordinary Shares Number  1.642679e+10         NaN
# Share Issued            1.642679e+10         NaN
# Net Debt                8.977900e+10         NaN
# Total Debt              1.365220e+11         NaN
#
# Income Statement:
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.410000e-01
# ...

# %%
stocklist=[]
stocklist= capital_market.equity_list().head(1)
stocklist= stocklist['SYMBOL'] + '.NS'
print(stocklist)

for sym in stocklist:
    try:
        tiker=yf.Ticker(stocklist)
        print(tiker)
    except Exception as e:
        print(f"Error with symbol {sym}: {e}")
# Out:
# 0    20MICRONS.NS
# Name: SYMBOL, dtype: object
# Error with symbol 20MICRONS.NS: 'Series' object has no attribute 'upper'

# %%
import logging
import yfinance as yf
import pandas as pd

# Suppress yfinance debug logs
logging.getLogger("yfinance").setLevel(logging.WARNING)

# Get the stock symbols and add ".NS"
stocklist = capital_market.equity_list().head(5)
symbols = stocklist['SYMBOL'] + '.NS'

# Prepare list to collect data
data = []


# Loop through each symbol
for sym in symbols:
    try:
        data={'Symbol': symbol, 'Company Name': info.get('longName', 'N/A'), 'Sector': info.get('sector','N/A'),
               'Industry': info.get(sindustry's 'N/A'), 'Mairket Cap': info.geWmarketCapl, 'N/A'), 'PIE Ratio': info.get('trailingPE', 'N/A'), 'Forward P/E': info.get('forwardPE', 'N/A'), 'PEG Ratio': info.get(IpegRatiol, 'N/A'), 'Price to Book': info.get('priceToBook', 'N/A'), 'EV/EBITDA': info.geWenterpriseToEbitdas, 'N/A'), 'Profit Margin': info.get(IprofitMargins', 'N/A'), 'Operating Margin': info.geWoperatingMarginsa, 'N/A'), 'ROE': info.get('returnOnEquity', 'N/A'), 'ROA': info.get(lreturnOnAssets', 'N/A'), 'Revenue': info.get('totalRevenue', 'N/A'), 'Revenue Per Share': info.get('revenuePerShare', 'N/A'), 'Quarterly Revenue Growth': info.get('quartertyRevenueGrowth', 'N/A'), 'Gross Profit': info.get('grossProfits', 'N/A'), 'EBITDA': info.get('ebitda', 'N/A'), 'Net Income': info.get('netIncomeToCommon', 'N/A'), 'EPS': info.get('trailingEps', 'N/A'), 'Quarterly Earnings Growth': info.get(IquarterlyEarningsGrowths„ 'N/A'), 'Total Cash': info.geWtotalCash', 'N/A'), 'Total Debt': info.get(ltotalDebt', 'N/A'), 'Debt To Equity': info.get('debtToEquity', 'N/A'), 'Current Ratio': info.geWcurrentRatiol, 'N/A'), 'Book Value': info.geWbookValue', 'N/A'), 'Free Cash Flow': info.get('freeCashflow', 'N/A'), 'Dividend Rate': info.get(IdividendRate', 'N/A'),
        }
        data.append({
            'Symbol': sym,
            'Name': name,
            'Sector': sector,
            'Industry': industry,
            'Market Cap': market_cap
        })
        print(f"Loaded ticker for {sym}")
    except Exception as e:
        print(f"Error with symbol {sym}: {e}")

# Create a DataFrame for table display
df = pd.DataFrame(data)
print(df)
# Out:
#   Cell In[38], line 19
# ...
