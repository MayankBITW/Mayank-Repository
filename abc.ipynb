# %%
pip install nselib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nselib
from nselib import capital_market
import pandas as pd

# %%
capital_market.bhav_copy_equities('09-06-2025')
capital_market.
# Out:
#           TradDt       BizDt Sgmt  Src  ... Rsvd1  Rsvd2 Rsvd3 Rsvd4
# 0     2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 1     2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 2     2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 3     2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 4     2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# ...          ...         ...  ...  ...  ...   ...    ...   ...   ...
# 3076  2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 3077  2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 3078  2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 3079  2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
# 3080  2025-06-09  2025-06-09   CM  NSE  ...   NaN    NaN   NaN   NaN
#
# [3081 rows x 34 columns]
